# %%
import numpy as np
from scipy.interpolate import lagrange
import matplotlib.pyplot as plt

x = np.array([0, 1, 2])
y = x**2
poly = lagrange(x, y)

x_new = np.arange(0.0,2.0,0.2)
y_New=Polynomial(poly.coef[::-1])(x_new)
plt.plot(x_new, y_New, label='Polynomial')
plt.show()

# %%
x = np.array([-1, 0, 1])
y = np.array([-7, -10, -5])
poly = lagrange(x, y)

x_new = np.arange(-1.0,1.2,0.2)
y_New=Polynomial(poly.coef[::-1])(x_new)
plt.plot(x_new, y_New, label='Polynomial')
plt.scatter(x, y, label='ground thruth')
plt.show()

# %%
x = np.arange(-1.0,1.2,0.01)
y = 1/(1+25*x**2)


x_test = np.arange(-1.0,1.2,0.2)
y_test = 1/(1+25*x_test**2)
poly = lagrange(x_test, y_test)
x_new = np.arange(-1.0,1.0,0.02)
y_new=Polynomial(poly.coef[::-1])(x_new)
plt.plot(x_new, y_new, label='Polynomial')
plt.plot(x, y, label='ground thruth')
plt.show()
